# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report 
from sklearn import tree

# %%
#loading data
data=load_iris()

# %%
#preparing data
x=pd.DataFrame(data.data,columns=data.feature_names)
y=data.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
#model building
model=DecisionTreeClassifier()

# %%
tree=model.fit(x_train,y_train)

# %%
#predicting 
preds=tree.predict(x_test)

# %%
y_test
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 1, 1, 1, 2, 0, 2, 0,
#        0])

# %%
accuracy=accuracy_score(y_test,preds)

# %%
#displaying accuracy
accuracy
# Out:
# 0.9777777777777777

# %%
# !pip3 install graphviz
import graphviz
# Out:
# Requirement already satisfied: graphviz in c:\programdata\anaconda3\lib\site-packages (0.15)

# %%
# !pip3 install pydot plus
# Out:
# Collecting pydot
#   Downloading pydot-1.4.1-py2.py3-none-any.whl (19 kB)
# Collecting plus
#   Downloading plus-1994.12.4-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\programdata\anaconda3\lib\site-packages (from pydot) (2.4.7)
# Collecting visdom
#   Downloading visdom-0.1.8.9.tar.gz (676 kB)
# Requirement already satisfied: numpy>=1.8 in c:\programdata\anaconda3\lib\site-packages (from visdom->plus) (1.18.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from visdom->plus) (1.5.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from visdom->plus) (2.24.0)
# Requirement already satisfied: tornado in c:\programdata\anaconda3\lib\site-packages (from visdom->plus) (6.0.4)
# Requirement already satisfied: pyzmq in c:\programdata\anaconda3\lib\site-packages (from visdom->plus) (19.0.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from visdom->plus) (1.15.0)
# Collecting jsonpatch
#   Downloading jsonpatch-1.28-py2.py3-none-any.whl (12 kB)
# Collecting torchfile
#   Downloading torchfile-0.1.0.tar.gz (5.2 kB)
# Collecting websocket-client
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from visdom->plus) (7.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->visdom->plus) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->visdom->plus) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->visdom->plus) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->visdom->plus) (2020.6.20)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.0-py2.py3-none-any.whl (7.6 kB)
# Building wheels for collected packages: visdom, torchfile
#   Building wheel for visdom (setup.py): started
#   Building wheel for visdom (setup.py): finished with status 'done'
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655257 sha256=c5c6898abf62abbb3c201a48c74087e8c30a0fb9797b6655e2ce23b8a5236f72
#   Stored in directory: c:\users\noor\appdata\local\pip\cache\wheels\6e\f5\76\7906cebf407d8dbf3b26cb28800b7d3b486ae7e7c8859a5748
#   Building wheel for torchfile (setup.py): started
#   Building wheel for torchfile (setup.py): finished with status 'done'
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5716 sha256=2d7ce054dbfa99c2118db6f1f6089c0c35722bef6cedd3f5441d47f82c362e5c
#   Stored in directory: c:\users\noor\appdata\local\pip\cache\wheels\b9\99\d1\9f3f4411a958a22ccf782e33c7238a07f04a9597f2f3b38792
# Successfully built visdom torchfile
# Installing collected packages: pydot, jsonpointer, jsonpatch, torchfile, websocket-client, visdom, plus
# Successfully installed jsonpatch-1.28 jsonpointer-2.0 plus-1994.12.4 pydot-1.4.1 torchfile-0.1.0 visdom-0.1.8.9 websocket-client-0.57.0

# %%
#representing in text format
text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- feature_2 <= 2.35
# |   |--- class: 0
# |--- feature_2 >  2.35
# |   |--- feature_2 <= 4.95
# |   |   |--- feature_3 <= 1.65
# |   |   |   |--- class: 1
# |   |   |--- feature_3 >  1.65
# |   |   |   |--- feature_1 <= 3.10
# |   |   |   |   |--- class: 2
# |   |   |   |--- feature_1 >  3.10
# |   |   |   |   |--- class: 1
# |   |--- feature_2 >  4.95
# |   |   |--- feature_3 <= 1.75
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: 2
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: 1
# |   |   |--- feature_3 >  1.75
# |   |   |   |--- class: 2

# %%
#plotting decision tree 
fig = plt.figure(figsize=(25,20)) 
plot=tree.plot_tree(model, 
                   feature_names=data.feature_names,  
                   class_names=data.target_names,
                   filled=True);

# %%
#classification report
report=classification_report(y_test,preds)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
